# %%
import pandas as pd

# %%
df1 = pd.read_excel("/content/drive/MyDrive/Datasets/Aracaju.xlsx") 
df2 = pd.read_excel("/content/drive/MyDrive/Datasets/Fortaleza.xlsx") 
df3 = pd.read_excel("/content/drive/MyDrive/Datasets/Natal.xlsx") 
df4 = pd.read_excel("/content/drive/MyDrive/Datasets/Recife.xlsx") 
df5 = pd.read_excel("/content/drive/MyDrive/Datasets/Salvador.xlsx")

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 189      Natal 2019-01-02  139.73    1037     2
# 41     Aracaju 2018-01-01  229.64    1520     8
# 99      Recife 2019-01-01  136.72     980     4
# 68      Recife 2019-01-01  175.45     980     3
# 218   Salvador 2019-01-02  189.12    1036     3
# 15     Aracaju 2018-01-01  153.28    1523     6
# 99     Aracaju 2018-01-01  139.32    1521     3
# 221   Salvador 2019-01-02  142.23    1035     2
# 29    Salvador 2019-01-01    9.27    1034     1
# 97    Salvador 2019-01-01   39.91    1037     3
# 106  Fortaleza 2019-01-01   28.42    1002     3
# 54       Natal 2018-10-03  373.00     852     4
# 104     Recife 2019-01-01   40.11     983     5
# 85   Fortaleza 2019-01-01  149.00    1005     3
# 29      Recife 2019-01-01   10.18     980     8

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita
# 25       Natal 2019-01-13  611.00    852     2  1222.00
# 204      Natal 2019-01-02  151.41   1037     2   302.82
# 140   Salvador 2019-03-02   20.79   1036     2    41.58
# 76      Recife 2019-01-01   17.86    980     5    89.30
# 163      Natal 2019-01-02   17.66   1036     3    52.98
# 116     Recife 2019-03-02   79.10    982     2   158.20
# 139     Recife 2019-03-02  141.16    980     7   988.12
# 126  Fortaleza 2019-03-02   41.87    980     8   334.96
# 189   Salvador 2019-01-02  139.73   1037     2   279.46
# 215      Natal 2019-01-02  203.84   1036     1   203.84
# 134   Salvador 2019-03-02  125.90   1036     1   125.90
# 31     Aracaju 2018-01-01  171.16   1520     9  1540.44
# 73    Salvador 2019-01-01    8.39   1037     1     8.39
# 87      Recife 2019-01-01  210.06    983     4   840.24
# 108   Salvador 2019-03-02   11.72   1037     1    11.72
# 198      Natal 2019-01-02   13.65   1037     3    40.95
# 6      Aracaju 2018-01-01   35.50   1522     2    71.00
# 8       Recife 2019-02-11   56.47    980     6   338.82
# 3      Aracaju 2018-01-01    3.01   1521     7    21.07
# 129      Natal 2019-01-02  125.66   1037     1   125.66

# %%
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(4, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0

# %%
df.nsmallest(4, "Receita")
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34   1522     1     3.34
# 65     Recife 2019-01-01    4.01    981     1     4.01
# 92      Natal 2019-01-02    4.57   1035     1     4.57
# 92   Salvador 2019-01-01    4.57   1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita
# 228   Salvador 2019-01-02    6.87   1037     3    20.61
# 198      Natal 2019-01-02   13.65   1037     3    40.95
# 23   Fortaleza 2019-01-01   85.90   1004     5   429.50
# 100    Aracaju 2018-01-01  180.57   1520     6  1083.42
# 76   Fortaleza 2019-01-01   38.61   1004     4   154.44
# 3     Salvador 2019-02-10  176.34   1037     3   529.02
# 2     Salvador 2019-02-10  173.59   1035     3   520.77
# 131   Salvador 2019-03-02   63.48   1037     3   190.44
# 50      Recife 2019-01-01    7.24    983     4    28.96
# 102    Aracaju 2018-01-01    7.29   1523     1     7.29

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df["Ano_de_Venda"] = df['Data'].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_de_Venda
# 151   Salvador 2019-01-02   14.63   1035     1    14.63          2019
# 39   Fortaleza 2019-01-01  176.51   1005     1   176.51          2019
# 217      Natal 2019-01-02   37.65   1036     2    75.30          2019
# 78     Aracaju 2018-01-01  154.85   1522     9  1393.65          2018
# 55   Fortaleza 2019-01-01  214.73   1002     4   858.92          2019

# %%
df["Mes_Venda"], df["Dia_Venda"] = (df["Data"].dt.month, df['Data'].dt.day)

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_de_Venda  \
# 59       Natal 2018-01-15  369.00    853     2   738.00          2018
# 76   Fortaleza 2019-01-01   38.61   1004     4   154.44          2019
# 82     Aracaju 2018-01-01  150.48   1522     4   601.92          2018
# 178   Salvador 2019-01-02   39.28   1037     3   117.84          2019
# 20      Recife 2019-01-01   42.35    982     3   127.05          2019
# 237      Natal 2019-01-03   38.06   1036     3   114.18          2019
# 28   Fortaleza 2019-01-01   34.88   1004     3   104.64          2019
# 179      Natal 2019-01-02   64.95   1036     1    64.95          2019
# 42       Natal 2019-03-02  775.00    854     2  1550.00          2019
# 64   Fortaleza 2019-01-01  110.31   1005     4   441.24          2019
#
#      Mes_Venda  Dia_Venda
# 59           1         15
# 76           1          1
# 82           1          1
# 178          1          2
# 20           1          1
# 237          1          3
# 28           1          1
# 179          1          2
# 42           3          2
# 64           1          1

# %%
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["diferenca_dias"] = df['Data'] - df['Data'].min()

# %%
df.sample(12)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_de_Venda  \
# 25       Natal 2019-01-13  611.00    852     2  1222.00          2019
# 121  Fortaleza 2019-03-02   41.55    981     3   124.65          2019
# 5     Salvador 2019-01-01  179.20   1037     3   537.60          2019
# 7    Fortaleza 2019-02-11   35.50   1003     2    71.00          2019
# 139   Salvador 2019-03-02  169.01   1036     1   169.01          2019
# 101     Recife 2019-01-01  172.55    983     7  1207.85          2019
# 126    Aracaju 2018-01-01   13.41   1520     7    93.87          2018
# 88     Aracaju 2018-01-01  190.67   1521     5   953.35          2018
# 201      Natal 2019-01-02   86.61   1036     1    86.61          2019
# 72     Aracaju 2018-01-01  168.95   1523     7  1182.65          2018
# 94   Fortaleza 2019-01-01  150.49   1003     5   752.45          2019
# 82    Salvador 2019-01-01  207.88   1035     1   207.88          2019
#
#      Mes_Venda  Dia_Venda diferenca_dias
# 25           1         13       377 days
# 121          3          2       425 days
# 5            1          1       365 days
# 7            2         11       406 days
# 139          3          2       425 days
# 101          1          1       365 days
# 126          1          1         0 days
# 88           1          1         0 days
# 201          1          2       366 days
# 72           1          1         0 days
# 94           1          1       365 days
# 82           1          1       365 days

# %%
df["Trimestre_Vendas"] = df['Data'].dt.quarter

# %%
df.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_de_Venda  \
# 51     Aracaju 2018-01-01   40.58   1522     6   243.48          2018
# 42   Fortaleza 2019-01-01   38.71   1004     5   193.55          2019
# 34    Salvador 2019-01-01   36.54   1037     3   109.62          2019
# 178      Natal 2019-01-02   39.28   1037     3   117.84          2019
# 62      Recife 2019-01-01   23.04    983     6   138.24          2019
# 106   Salvador 2019-01-01  149.19   1035     2   298.38          2019
# 210      Natal 2019-01-02  197.64   1035     1   197.64          2019
# 60    Salvador 2019-01-01   96.01   1034     2   192.02          2019
# 78     Aracaju 2018-01-01  154.85   1522     9  1393.65          2018
# 222      Natal 2019-01-02   43.96   1037     1    43.96          2019
# 124   Salvador 2019-03-02   44.82   1034     3   134.46          2019
# 101    Aracaju 2018-01-01   16.62   1520     9   149.58          2018
# 126     Recife 2019-03-02   41.87    980     8   334.96          2019
# 226   Salvador 2019-01-02   38.32   1035     2    76.64          2019
# 74   Fortaleza 2019-01-01  163.09   1005     5   815.45          2019
# 196   Salvador 2019-01-02  145.09   1036     2   290.18          2019
# 98   Fortaleza 2019-01-01   15.00   1005     2    30.00          2019
# 123      Natal 2019-01-02  127.45   1036     3   382.35          2019
# 108      Natal 2019-01-02   11.72   1037     1    11.72          2019
# 96     Aracaju 2018-01-01   85.92   1521     2   171.84          2018
#
#      Mes_Venda  Dia_Venda diferenca_dias  Trimestre_Vendas
# 51           1          1         0 days                 1
# 42           1          1       365 days                 1
# 34           1          1       365 days                 1
# 178          1          2       366 days                 1
# 62           1          1       365 days                 1
# 106          1          1       365 days                 1
# 210          1          2       366 days                 1
# 60           1          1       365 days                 1
# 78           1          1         0 days                 1
# 222          1          2       366 days                 1
# 124          3          2       425 days                 1
# 101          1          1         0 days                 1
# 126          3          2       425 days                 1
# 226          1          2       366 days                 1
# 74           1          1       365 days                 1
# 196          1          2       366 days                 1
# 98           1          1       365 days                 1
# 123          1          2       366 days                 1
# 108          1          2       366 days                 1
# 96           1          1         0 days                 1

# %%
Vendas_Marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
Vendas_Marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_de_Venda  \
# 137   Salvador 2019-03-02   51.66   1036     3   154.98          2019
# 134   Salvador 2019-03-02  125.90   1036     1   125.90          2019
# 120  Fortaleza 2019-03-02  184.90    982     4   739.60          2019
# 130   Salvador 2019-03-02   59.78   1036     1    59.78          2019
# 119   Salvador 2019-03-02  136.37   1034     2   272.74          2019
# 126  Fortaleza 2019-03-02   41.87    980     8   334.96          2019
# 111  Fortaleza 2019-03-02    8.00    981     3    24.00          2019
# 127  Fortaleza 2019-03-02   39.56    982     8   316.48          2019
# 113  Fortaleza 2019-03-02   38.63    980     2    77.26          2019
# 118  Fortaleza 2019-03-02   17.70    981     5    88.50          2019
# 19       Natal 2019-03-31  282.00    854     2   564.00          2019
# 137  Fortaleza 2019-03-02   51.99    983     3   155.97          2019
# 110     Recife 2019-03-02   51.98    983     6   311.88          2019
# 125     Recife 2019-03-02   37.60    983     4   150.40          2019
# 131     Recife 2019-03-02  139.07    982     6   834.42          2019
# 121  Fortaleza 2019-03-02   41.55    981     3   124.65          2019
# 109     Recife 2019-03-02   18.90    982     6   113.40          2019
# 117   Salvador 2019-03-02   39.41   1034     1    39.41          2019
# 121     Recife 2019-03-02   41.55    981     3   124.65          2019
# 7        Natal 2019-03-18  886.00    853     4  3544.00          2019
#
#      Mes_Venda  Dia_Venda diferenca_dias  Trimestre_Vendas
# 137          3          2       425 days                 1
# 134          3          2       425 days                 1
# 120          3          2       425 days                 1
# 130          3          2       425 days                 1
# 119          3          2       425 days                 1
# 126          3          2       425 days                 1
# 111          3          2       425 days                 1
# 127          3          2       425 days                 1
# 113          3          2       425 days                 1
# 118          3          2       425 days                 1
# 19           3         31       454 days                 1
# 137          3          2       425 days                 1
# 110          3          2       425 days                 1
# 125          3          2       425 days                 1
# 131          3          2       425 days                 1
# 121          3          2       425 days                 1
# 109          3          2       425 days                 1
# 117          3          2       425 days                 1
# 121          3          2       425 days                 1
# 7            3         18       441 days                 1

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'].value_counts(ascending=False).plot.bar();

# %%
df['LojaID'].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie();

# %%
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total de Vendas por Cidade", color="red")
plt.xlabel("Cidades")
plt.ylabel("Total Vendas");

# %%
plt.style.use("ggplot")

# %%
df.groupby(df['Mes_Venda'])["Qtde"].sum().plot(title = "Total de Produtos vendida X Mês")
plt.xlabel("Mês")
plt.ylabel("Total de Produtos Vendidos")
plt.legend();

# %%
df_2019 = df[df["Ano_de_Venda"] == 2019]

# %%
df_2019.groupby(df_2019['Mes_Venda'])["Qtde"].sum().plot(marker = "o")
plt.xlabel("Mês")
plt.ylabel("Total de Produtos Vendidos")
plt.legend();

# %%
plt.hist(df['Qtde'], color="orangered");

# %%
plt.scatter(x=df_2019["Dia_Venda"], y = df_2019['Receita']);

# %%
df.dtypes
# Out:
# Cidade                       object
# Data                 datetime64[ns]
# Vendas                      float64
# LojaID                       object
# Qtde                          int64
# Receita                     float64
# Ano_de_Venda                  int64
# Mes_Venda                     int64
# Dia_Venda                     int64
# diferenca_dias      timedelta64[ns]
# Trimestre_Vendas              int64
# dtype: object

# %%
df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum().plot(marker = "v")
plt.title("Quantidade de Produtos Vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend()
plt.savefig("grafico QTDE x MES.png")
